# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv",encoding="latin-1")
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df['Area'].count()
# Out:
# 60943

# %%
group= df.groupby('Area')['Y2017'].sum()

group
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %% [markdown]
# question2

# %%
df.groupby(['Area'])['Y2017'].min().reset_index()
# Out:
#                            Area   Y2017
# 0                       Algeria   -81.0
# 1                        Angola  -250.0
# 2                         Benin  -125.0
# 3                      Botswana   -38.0
# 4                  Burkina Faso  -281.0
# 5                    Cabo Verde    -7.0
# 6                      Cameroon  -147.0
# 7      Central African Republic    -1.0
# 8                          Chad   -37.0
# 9                       Comoros     0.0
# 10                        Congo    -4.0
# 11                Côte d'Ivoire  -244.0
# 12                     Djibouti    -2.0
# 13                        Egypt -1582.0
# 14                     Eswatini  -100.0
# 15                     Ethiopia  -792.0
# 16                 Ethiopia PDR     0.0
# 17                        Gabon   -37.0
# 18                       Gambia    -2.0
# 19                        Ghana  -121.0
# 20                       Guinea  -108.0
# 21                Guinea-Bissau    -3.0
# ...

# %% [markdown]
# question 3

# %%
df.groupby(['Area'])['Y2017'].sum().reset_index()
# Out:
#                            Area       Y2017
# 0                       Algeria   325644.27
# 1                        Angola   229159.57
# 2                         Benin   124771.22
# 3                      Botswana    22101.30
# 4                  Burkina Faso   101855.07
# 5                    Cabo Verde    14650.74
# 6                      Cameroon   232030.43
# 7      Central African Republic    29937.00
# 8                          Chad    71594.68
# 9                       Comoros       59.84
# 10                        Congo    41181.68
# 11                Côte d'Ivoire   224599.01
# 12                     Djibouti    22729.91
# 13                        Egypt   866379.92
# 14                     Eswatini    54343.33
# 15                     Ethiopia   448683.76
# 16                 Ethiopia PDR        0.00
# 17                        Gabon    27979.64
# 18                       Gambia    23154.18
# 19                        Ghana   337599.06
# ...

# %% [markdown]
# question7

# %% [markdown]
# total number of processing in 2017

# %%
Sum= df['Y2017'].sum()
Sum
# Out:
# 8375729.189999999
